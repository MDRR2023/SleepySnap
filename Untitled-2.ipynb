# %%
import numpy as np 
import pandas as pd 
import os
import tensorflow as tf

from glob import glob
from tqdm import tqdm

import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Loading the Images

# %%
X = []
Y = []

active_subjects_dir = r'train\Active_Subjects'
fatigue_subjects_dir = r'train\Fatigue_Subjects'

# Mencari gambar dalam direktori active_subjects_dir
for file_path in tqdm(glob(os.path.join(active_subjects_dir, '*.*'))):
    temp = np.array(Image.open(file_path).resize((124, 124)))
    X.append(temp)
    Y.append(1)

# Mencari gambar dalam direktori fatigue_subjects_dir
for file_path in tqdm(glob(os.path.join(fatigue_subjects_dir, '*.*'))):
    temp = np.array(Image.open(file_path).resize((124, 124)))
    X.append(temp)
    Y.append(0)
# Out:
# 100%|██████████| 4560/4560 [02:11<00:00, 34.72it/s]
# 100%|██████████| 4560/4560 [01:51<00:00, 40.89it/s]

# %%
# Pilih gambar dari dataset yang ingin Anda lihat
selected_image = X[99]

# Invers normalisasi: mengalikan kembali dengan 255
# original_image = (selected_image * 255.0).astype('uint8')

# Hilangkan dimensi yang tidak diperlukan jika diperlukan
original_image = selected_image.squeeze()

# Tampilkan gambar
plt.imshow(original_image)
plt.show()

# %% [markdown]
# ## Normalizing the images (with any algorithm)

# %%
X = np.array(X)
X = X/255.0
Y = np.array(Y)

# %%
# Pilih gambar dari dataset yang ingin Anda lihat
selected_image = X[99]

# Invers normalisasi: mengalikan kembali dengan 255
# original_image = (selected_image * 255.0).astype('uint8')

# Hilangkan dimensi yang tidak diperlukan jika diperlukan
original_image = selected_image.squeeze()

# Tampilkan gambar
plt.imshow(selected_image)
plt.show()

# %% [markdown]
# ## Spliting the dataset into training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %% [markdown]
# ## CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Conv2D, BatchNormalization, MaxPooling2D,Dropout, Flatten

model = tf.keras.models.Sequential([
      Input(shape=(124, 124, 3)),

      Conv2D(filters = 32, kernel_size = 5, strides = 1, activation = 'relu'),
      Conv2D(filters = 32, kernel_size = 5, strides = 1, activation = 'relu', use_bias=False),
      BatchNormalization(),
      MaxPooling2D(strides = 2),
      Dropout(0.3),

      Conv2D(filters = 64, kernel_size = 3, strides = 1, activation = 'relu'),
      Conv2D(filters = 64, kernel_size = 3, strides = 1, activation = 'relu', use_bias=False),
      BatchNormalization(),
      MaxPooling2D(strides = 2),
      Dropout(0.3),

      Flatten(),
      Dense(units  = 128, activation = 'relu', use_bias=False),
      BatchNormalization(),

      Dense(units = 64, use_bias=False, activation = 'relu'),

      Dense(units = 42, use_bias=False, activation = 'relu'),
      BatchNormalization(),
      Dropout(0.3),

      Dense(units = 1, activation = 'sigmoid')
  ])

# %% [markdown]
# ## Compiling the Model

# %%
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Training of the Model

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='bestModel5.keras',
    save_weights_only=False,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose =1)
model.fit(x_train, y_train, validation_split=0.2, epochs=5, batch_size=32, callbacks=callback)
# Out:
# Epoch 1/5
# 153/153 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.8670
# Epoch 1: val_loss improved from inf to 0.31394, saving model to bestModel5.keras
# 153/153 [==============================] - 134s 876ms/step - loss: 0.3079 - accuracy: 0.8670 - val_loss: 0.3139 - val_accuracy: 0.8502
# Epoch 2/5
# 153/153 [==============================] - ETA: 0s - loss: 0.3056 - accuracy: 0.8666
# Epoch 2: val_loss did not improve from 0.31394
# 153/153 [==============================] - 132s 863ms/step - loss: 0.3056 - accuracy: 0.8666 - val_loss: 0.3161 - val_accuracy: 0.8437
# Epoch 3/5
# 153/153 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8707
# Epoch 3: val_loss improved from 0.31394 to 0.30638, saving model to bestModel5.keras
# 153/153 [==============================] - 145s 947ms/step - loss: 0.2921 - accuracy: 0.8707 - val_loss: 0.3064 - val_accuracy: 0.8625
# Epoch 4/5
# 153/153 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.8738
# Epoch 4: val_loss improved from 0.30638 to 0.29524, saving model to bestModel5.keras
# 153/153 [==============================] - 132s 865ms/step - loss: 0.2871 - accuracy: 0.8738 - val_loss: 0.2952 - val_accuracy: 0.8568
# Epoch 5/5
# 153/153 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.8789
# Epoch 5: val_loss did not improve from 0.29524
# 153/153 [==============================] - 120s 782ms/step - loss: 0.2705 - accuracy: 0.8789 - val_loss: 0.3530 - val_accuracy: 0.8453

# %% [markdown]
# ## Model Evaluation

# %%
model.evaluate(x_test, y_test)
# Out:
# 95/95 [==============================] - 20s 214ms/step - loss: 0.3489 - accuracy: 0.8495
# [0.348900705575943, 0.8495016694068909]

# %% [markdown]
# ## Loading the Model Performance

# %%
from keras.models import load_model
best_model = load_model('bestModel5.h5')
#best_model.evaluate(x_test, y_test)
best_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 120, 120, 32)      2432
#
#  conv2d_17 (Conv2D)          (None, 116, 116, 32)      25600
#
#  batch_normalization_16 (Bat  (None, 116, 116, 32)     128
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 58, 58, 32)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 58, 58, 32)        0
#
#  conv2d_18 (Conv2D)          (None, 56, 56, 64)        18496
#
#  conv2d_19 (Conv2D)          (None, 54, 54, 64)        36864
#
#  batch_normalization_17 (Bat  (None, 54, 54, 64)       256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 27, 27, 64)       0
#  2D)
#
#  dropout_13 (Dropout)        (None, 27, 27, 64)        0
#
#  flatten_4 (Flatten)         (None, 46656)             0
#
#  dense_16 (Dense)            (None, 128)               5971968
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  dense_17 (Dense)            (None, 64)                8192
#
#  dense_18 (Dense)            (None, 42)                2688
#
#  batch_normalization_19 (Bat  (None, 42)               168
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 42)                0
#
#  dense_19 (Dense)            (None, 1)                 43
#
# =================================================================
# Total params: 6,067,347
# Trainable params: 6,066,815
# Non-trainable params: 532
# _________________________________________________________________

# %%
from keras.models import load_model
from keras.models import model_from_json

# Load model from the .h5 file
best_model = load_model('bestModel5.h5')

# Convert the model to JSON format
model_json = best_model.to_json()

# Save the JSON model architecture to a file
with open('bestModel5.json', 'w') as json_file:
    json_file.write(model_json)

# You can also save the model's weights to a separate file if needed
best_model.save_weights('bestModel5_weights.h5')

# %% [markdown]
# ## Changing the dimensions and Plotting the trained images

# %%
accuracies = []  # Membuat list untuk menyimpan akurasi

for i, image in enumerate(x_test[0:15]):
    result = best_model.predict(np.expand_dims(image, 0))
    
    # Kembalikan gambar ke dalam rentang [0, 255] dari [0, 1] jika sudah dinormalisasi
    i_display = image.squeeze() * 255 if np.max(image) <= 1 else image.squeeze()
    
    plt.imshow(i_display.astype('uint8'))  # Pastikan tipe data adalah uint8
    plt.show()
    
    if result > 0.5:
        print('Seger Banget!')
    else:
        print('Kelelahan!')
    
    # Mengambil akurasi dari model untuk data saat ini
    accuracy = best_model.evaluate(np.expand_dims(image, 0), np.array([y_test[i]]))[1]
    accuracies.append(accuracy)  # Menyimpan akurasi dalam list

# Mencetak akurasi untuk setiap percobaan
for i, acc in enumerate(accuracies):
    print(f"Sampel {i+1} - Akurasi: {acc}")
# Out:
# 1/1 [==============================] - 0s 160ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0076 - accuracy: 1.0000
# 1/1 [==============================] - 0s 30ms/step
# Seger Banget!
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0325 - accuracy: 1.0000
# 1/1 [==============================] - 0s 32ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 30ms/step - loss: 2.1685 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0139 - accuracy: 1.0000
# 1/1 [==============================] - 0s 37ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1352 - accuracy: 1.0000
# 1/1 [==============================] - 0s 37ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0042 - accuracy: 1.0000
# 1/1 [==============================] - 0s 31ms/step
# Seger Banget!
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0042 - accuracy: 1.0000
# 1/1 [==============================] - 0s 36ms/step
# Seger Banget!
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1455 - accuracy: 1.0000
# 1/1 [==============================] - 0s 30ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0033 - accuracy: 1.0000
# 1/1 [==============================] - 0s 33ms/step
# Seger Banget!
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0117 - accuracy: 1.0000
# 1/1 [==============================] - 0s 31ms/step
# Seger Banget!
# 1/1 [==============================] - 0s 32ms/step - loss: 1.3313 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step
# Seger Banget!
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0726 - accuracy: 1.0000
# 1/1 [==============================] - 0s 34ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0024 - accuracy: 1.0000
# 1/1 [==============================] - 0s 28ms/step
# Kelelahan!
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0045 - accuracy: 1.0000
# 1/1 [==============================] - 0s 68ms/step
# Seger Banget!
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0950 - accuracy: 1.0000
# Sampel 1 - Akurasi: 1.0
# Sampel 2 - Akurasi: 1.0
# Sampel 3 - Akurasi: 0.0
# Sampel 4 - Akurasi: 1.0
# Sampel 5 - Akurasi: 1.0
# Sampel 6 - Akurasi: 1.0
# Sampel 7 - Akurasi: 1.0
# Sampel 8 - Akurasi: 1.0
# Sampel 9 - Akurasi: 1.0
# Sampel 10 - Akurasi: 1.0
# Sampel 11 - Akurasi: 0.0
# Sampel 12 - Akurasi: 1.0
# Sampel 13 - Akurasi: 1.0
# Sampel 14 - Akurasi: 1.0
# Sampel 15 - Akurasi: 1.0

# %% [markdown]
# ## Prediction and Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(15, 5))

preds = best_model.predict(x_test)
preds = (preds >= 0.5).astype(np.int32)
cm = confusion_matrix(y_test, preds)
df_cm = pd.DataFrame(cm, index=['closed', 'Open'], columns=['Closed', 'Open'])
plt.subplot(121)
plt.title("Confusion matrix\n")
sns.heatmap(df_cm, annot=True, fmt="d", cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")
# Out:
# 95/95 [==============================] - 9s 95ms/step
# Text(0.5, 25.722222222222214, 'Actual')

# %% [markdown]
# ## Accuracy
# Evaluating the Accuracy

# %%
accuracy = best_model.evaluate(x_test, y_test)[1]
print("Accuracy:", accuracy)
# Out:
# 95/95 [==============================] - 9s 98ms/step - loss: 0.3089 - accuracy: 0.8608
# Accuracy: 0.8607973456382751
